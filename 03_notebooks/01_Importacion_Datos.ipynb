# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from pathlib import Path
import os

# %% [markdown]
# ## Importación de fuentes
# Los campos score_actividad y score_perfil son candidatos a data leakage. No sabemos si las vamos a tener en la realidad en producción

# %%
leads = pd.read_csv("../02_datos/01_Originales/Leads.csv", sep=";", encoding="utf-8")
print("shape:", leads.shape)
display(leads.head())
display(leads.dtypes.to_frame("dtype"))
# Out:
# shape: (9093, 21)
#        id                   origen          fuente no_enviar_email no_llamar  \
# 0  660737                      API            Chat              No        No
# 1  660728                      API  Organic Search              No        No
# 2  660727  Landing Page Submission  Direct Traffic              No        No
# 3  660719  Landing Page Submission  Direct Traffic              No        No
# 4  660681  Landing Page Submission          Google              No        No
#
#    compra  visitas_total  tiempo_en_site_total  paginas_vistas_visita  \
# 0       0            0.0                     0                    0.0
# 1       0            5.0                   674                    2.5
# 2       1            2.0                  1532                    2.0
# 3       0            1.0                   305                    1.0
# 4       1            2.0                  1428                    1.0
#
# ...

# %% [markdown]
# ## Análisis estructural

# %%
print("grain_candidate: one row per lead")
print("candidate_key: id")
print("id_unique:", leads["id"].is_unique)
print("id_nulls:", leads["id"].isna().sum())
print("duplicate_id_rows:", leads["id"].duplicated(keep=False).sum())
print("columns:", list(leads.columns))
print("shared_key_candidates:", [c for c in leads.columns if leads[c].nunique(dropna=False) == len(leads)])
print("duplicate_rows:", leads.duplicated().sum())
# Out:
# grain_candidate: one row per lead
# candidate_key: id
# id_unique: True
# id_nulls: 0
# duplicate_id_rows: 0
# columns: ['id', 'origen', 'fuente', 'no_enviar_email', 'no_llamar', 'compra', 'visitas_total', 'tiempo_en_site_total', 'paginas_vistas_visita', 'ult_actividad', 'ambito', 'ocupacion', 'conociste_google', 'conociste_revista', 'conociste_periodico', 'conociste_youtube', 'conociste_facebook', 'conociste_referencias', 'score_actividad', 'score_perfil', 'descarga_lm']
# shared_key_candidates: ['id']
# duplicate_rows: 0
